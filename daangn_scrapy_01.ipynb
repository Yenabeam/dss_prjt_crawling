# %%
import scrapy
import requests
from scrapy.http import TextResponse
import pandas as pd

# %%
# 1. Start project

# %%
# !scrapy startproject daangn
# Out:
# New Scrapy project 'daangn', using template directory '/home/ubuntu/.pyenv/versions/3.6.9/envs/python3/lib/python3.6/site-packages/scrapy/templates/project', created in:
#     /home/ubuntu/Code/09_project/02_crawling/daangn
#
# You can start your first spider with:
#     cd daangn
#     scrapy genspider example example.com

# %%
# 2. items.py

# %%
# %load daangn/daangn/items.py

# %%
# %%writefile daangn/daangn/items.py
# '''
# region = 거래지역; ~구~ 동까지 표기됨
# temperature = 거래 온도; 좋은 거래를 할수록 온도가 높아짐
# chat_counts = 판매자와 구매 관심자의 채팅이 오고 간 횟수
# watch_counts = 찜한 횟수
# '''
import scrapy


class DaangnItem(scrapy.Item):
    title = scrapy.Field() 
    user_id = scrapy.Field()
    temperature = scrapy.Field()
    region = scrapy.Field() 
    price = scrapy.Field() 
    link = scrapy.Field()
    desc = scrapy.Field() 
    chat_counts = scrapy.Field() 
    watch_counts = scrapy.Field() 
    view_counts = scrapy.Field()
# Out:
# Overwriting daangn/daangn/items.py

# %%
# 3. spider.py

# %%
# %%writefile daangn/daangn/spiders/spider.py
import string
import scrapy
from scrapy import Request
from daangn.items import DaangnItem

class DaangnSpider(scrapy.Spider):
    name = 'Daangn'
    start_urls = ["https://www.daangn.com/search/macbook/more/flea_market?page=1"]
    page_number = 2
    
    def parse(self, response):
        xp = "/html/body/article/a/@href"
        urls = response.xpath(xp).extract()
        # get full url
        urls =  list(map(response.urljoin, urls))
        return (Request(url, callback=self.parse_content) for url in urls)
    
    def parse_content(self, response):
        item = DaangnItem()
        item['title'] = response.xpath('//*[@id="article-title"]/text()')[0].extract().strip()
        item['price'] = response.xpath('//*[@id="article-price"]/text()')[0].extract().strip()
        desc = response.xpath('//*[@id="article-detail"]/p/text()').extract()
        item['desc'] = "".join(desc).replace('\n', '')
        item['user_id'] = response.xpath('//*[@id="nickname"]/text()')[0].extract().strip()
        item['temperature'] = response.xpath('//*[@id="temperature-wrap"]/dd/text()')[0].extract().strip()
        item['link'] = response.xpath('/html/head/link[1]/@href')[0].extract()
        item['region'] = response.xpath('//*[@id="region-name"]/text()')[0].extract().strip()
        counts = response.xpath('//*[@id="article-counts"]/text()')[0].extract().strip()
        item['chat_counts'] = counts.split('∙')[0].strip().split(' ')[1]
        item['watch_counts'] = counts.split('∙')[1].strip().split(' ')[1]
        item['view_counts'] = counts.split('∙')[2].strip().split(' ')[1]
       
        yield item
        
        next_page = 'https://www.daangn.com/search/macbook/more/flea_market?page=' + str(DaangnSpider.page_number)
        if DaangnSpider.page_number <= 800:
            DaangnSpider.page_number += 1
            yield response.follow(next_page, callback = self.parse)
# Out:
# Overwriting daangn/daangn/spiders/spider.py

# %%
# %%writefile daangn/daangn/mongodb.py
import pymongo
from datetime import datetime

today = datetime.now()

client = pymongo.MongoClient("mongodb://id:pwd@1.23.45.6:27017")
db = client.joongo
collection = db["D{}".format(today.strftime('%y%m%d%H'))]
# Out:
# Overwriting daangn/daangn/mongodb.py

# %%
# %%writefile daangn/daangn/pipelines.py


from itemadapter import ItemAdapter
from .mongodb import collection


class DaangnPipeline(object):
    def process_item(self, item, spider):
        columns = ["title","price","desc","user_id","temperature","link","region","chat_counts","watch_counts","view_counts"]
        data = {column: item[column] for column in columns}
        collection.insert(data)

        return item
# Out:
# Overwriting daangn/daangn/pipelines.py

# %%
# %%writefile run.sh
# cd daangn
# # rm items.csv
# scrapy crawl Daangn -o items.csv
# Out:
# Overwriting run.sh

# %%
# %%time
# !/bin/bash run.sh
# Out:
# 2020-11-24 19:21:32 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: daangn)
# 2020-11-24 19:21:32 [scrapy.utils.log] INFO: Versions: lxml 4.6.1.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.6.9 (default, Oct 16 2020, 02:01:21) - [GCC 7.5.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1h  22 Sep 2020), cryptography 3.2.1, Platform Linux-5.4.0-1029-aws-x86_64-with-debian-buster-sid
# 2020-11-24 19:21:32 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-11-24 19:21:32 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'daangn',
#  'NEWSPIDER_MODULE': 'daangn.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['daangn.spiders']}
# 2020-11-24 19:21:32 [scrapy.extensions.telnet] INFO: Telnet Password: b872d3c9bc24ef19
# 2020-11-24 19:21:32 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-11-24 19:21:32 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-11-24 19:21:32 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-11-24 19:21:32 [scrapy.middleware] INFO: Enabled item pipelines:
# ['daangn.pipelines.DaangnPipeline']
# 2020-11-24 19:21:32 [scrapy.core.engine] INFO: Spider opened
# 2020-11-24 19:21:32 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-11-24 19:21:32 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-11-24 19:21:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.daangn.com/robots.txt> (referer: None)
# 2020-11-24 19:21:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.daangn.com/search/macbook/more/flea_market?page=1> (referer: None)
# 2020-11-24 19:21:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.daangn.com/articles/154330347> (referer: https://www.daangn.com/search/macbook/more/flea_market?page=1)
# 2020-11-24 19:21:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.daangn.com/articles/154383568> (referer: https://www.daangn.com/search/macbook/more/flea_market?page=1)
# 2020-11-24 19:21:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.daangn.com/articles/154383587> (referer: https://www.daangn.com/search/macbook/more/flea_market?page=1)
# 2020-11-24 19:21:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.daangn.com/articles/146403990> (referer: https://www.daangn.com/search/macbook/more/flea_market?page=1)
# 2020-11-24 19:21:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.daangn.com/articles/151356238> (referer: https://www.daangn.com/search/macbook/more/flea_market?page=1)
# 2020-11-24 19:21:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.daangn.com/articles/154263336> (referer: https://www.daangn.com/search/macbook/more/flea_market?page=1)
# 2020-11-24 19:21:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.daangn.com/articles/150937538> (referer: https://www.daangn.com/search/macbook/more/flea_market?page=1)
# 2020-11-24 19:21:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.daangn.com/articles/151032265> (referer: https://www.daangn.com/search/macbook/more/flea_market?page=1)
# 2020-11-24 19:21:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.daangn.com/articles/154330347>
# {'chat_counts': '1',
#  'desc': '014년도 구입 최고사양 CTO 맥북 프로 A1278CPU : I7 최고사양 램 : 8기가그래픽 : HD4000고급사양하드 '
#          ': 초고속 애플 750GB벡라이트키보드 13.3인치 고 해상도 패널로직 원활하게 돌아가고 외장그래픽으로 무거운 그래픽 '
#          '작업도 잘 돌아갑니다',
#  'link': 'https://www.daangn.com/articles/154330347',
#  'price': '400,000원',
#  'region': '공주시 금학동',
#  'temperature': '36.5',
#  'title': '맥북프로 I7 CPU A1278프리미엄 맥북 - 최고사양',
#  'user_id': '김소연',
#  'view_counts': '54',
#  'watch_counts': '0'}
# 2020-11-24 19:21:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.daangn.com/articles/154383568>
# {'chat_counts': '0',
#  'desc': '서울',
#  'link': 'https://www.daangn.com/articles/154383568',
#  'price': '720,000원',
#  'region': '남구 신정3동',
#  'temperature': '38.4',
#  'title': '맥북 12인치 뉴맥북 2017',
#  'user_id': '하늘',
#  'view_counts': '11',
#  'watch_counts': '1'}
# 2020-11-24 19:21:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.daangn.com/articles/154383587>
# {'chat_counts': '0',
#  'desc': '맥북 에어 2014 13인치 ssd 128g프로세서 1.4GHz 듀얼코어 intel core i5-4260U메모리 8GB '
#          '1600 MHz DDR3(메모리업글)그래픽 intel he graphics  ***-****-**** MB애플로고 '
#          '불빛나옵니다보호스킨붙여서 써서 기스제로구요찍힘한군데는 사진에 올렸습니다@@@ 사진에없지만 박스셋입니다 '
#          '@@@정품충전기usb랜카드hdmi썬더볼트div usb키보드커버매직마우스어차피 안쓰는거 서비스로 다드립니다',
#  'link': 'https://www.daangn.com/articles/154383587',
#  'price': '430,000원',
#  'region': '고양시 일산서구 일산1동',
#  'temperature': '44.2',
#  'title': '맥북에어13인치 2014 Macbook Air',
#  'user_id': '당근왕검',
#  'view_counts': '28',
#  'watch_counts': '0'}
# 2020-11-24 19:21:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.daangn.com/articles/146403990>
# {'chat_counts': '5',
#  'desc': '맥북프로 레티나 13인치 입니다액정은 기본 필름입니다.하단 배면부 생활기스 있습니다사용하던 정품 아답터 충전기 '
#          '있습니다사무실과 집에서만 사용했습니다.구성품 맥북프로본체+아답터 입니다필요하시면 사용하던 파우치도 함께 드립니다.직거래 '
#          '원합니다.',
#  'link': 'https://www.daangn.com/articles/146403990',
#  'price': '500,000원',
#  'region': '금천구 가산동',
#  'temperature': '36.5',
#  'title': '애플 맥북 프로 레티나 MacBook Pro A1502 13인치 판매',
#  'user_id': '네오',
#  'view_counts': '734',
#  'watch_counts': '7'}
# 2020-11-24 19:21:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.daangn.com/articles/151356238>
# {'chat_counts': '1',
#  'desc': '* 256GB* 최근 수리* 포맷완료* 풀박스* 직거래해요* 깨끗하게 쓰시라고 알코올솜 드립니다일련번호는 '
#          '가렸구요,포맷한거라 그냥 바로 쓰시면됩니다매직마우스 케이블도 새거예요추가로 원하시는 사진있으시면 보내드리겠습니다관심있는 '
#          '선생님들 문의주셔요 :)',
#  'link': 'https://www.daangn.com/articles/151356238',
#  'price': '800,000원',
#  'region': '성동구 행당동',
#  'temperature': '36.5',
#  'title': '맥북프로 Macbook Pro, 13인치 Early 2015 & 애플 매직마우스2',
#  'user_id': '채니',
#  'view_counts': '469',
#  'watch_counts': '15'}
# 2020-11-24 19:21:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.daangn.com/articles/154263336>
# {'chat_counts': '0',
#  'desc': '맥북 프로 15인치 2013년도 고급형 판매합니다.i7 2.3 쿼드코어입니다.풀박이구요 잘돌아갑니다.배터리 사이클 23에 '
#          '상태 좋습니다!택배, 망포역 직거래합니다',
#  'link': 'https://www.daangn.com/articles/154263336',
#  'price': '850,000원',
#  'region': '수원시 영통구 망포동',
#  'temperature': '36.7',
#  'title': 'Macbook Pro (Retina, 15-inch, Late 2013) 맥북 프로 15인치 고급형 100만원',
#  'user_id': '최의현',
#  'view_counts': '85',
#  'watch_counts': '1'}
# 2020-11-24 19:21:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.daangn.com/articles/150937538>
# {'chat_counts': '4',
#  'desc': '맥북에어 기본형 스페이스그레이 팝니다 7월 구매 후 집에서만 사용했고유튜브 넷플릭스 시청위주로 사용했습니다사이클회수는 '
#          '18회입니다사진에 있는 가방, 키스킨 같이 드립니다 겉면에 보호필름도 붙여져있는데 불편하시면 제거하시면 됩니다 이제 사용할 '
#          '일이 없어 팝니다완전 깨끗하게 사용했습니다 하자 하나도 없는 거의 새상품입니다직거래위치는 경남 창원, 김해, 인근지역 '
#          '가능합니다 부산도 가능합니다 연락주세요\u200b1.1GHz 듀얼 코어 10세대 Intel Core i3프로세서(최대 '
#          '3.2GHz Turbo Boost)Intel Iris Plus Graphics8GB 3733MHz LPDDR4X '
#          '메모리256GB SSD 저장 장치¹',
#  'link': 'https://www.daangn.com/articles/150937538',
#  'price': '1,000,000원',
#  'region': '창원시 성산구 내동',
#  'temperature': '37.3',
#  'title': '맥북 에어 2020 (Macbook air 2020)',
#  'user_id': '허뚜뚜',
#  'view_counts': '608',
#  'watch_counts': '11'}
# 2020-11-24 19:21:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.daangn.com/articles/151032265>
# {'chat_counts': '0',
#  'desc': '맥북에어[Macbook air] 판매합니다13인치이고 케이스 착용하고 조심히 사용해서 제품 상태 좋습니다 구성은 본체와 '
#          '충전기만 있습니다CPU i5코어이고 하드 용량 128기가 입니다!!~배터리 사이클 수는 123입니다문의 많이 주세요!!~',
#  'link': 'https://www.daangn.com/articles/151032265',
#  'price': '530,000원',
#  'region': '성남시 분당구 금곡동',
#  'temperature': '35.7',
#  'title': 'MaCbook air 맥북/멕북 노트북 판매합니다',
#  'user_id': '야도르',
#  'view_counts': '235',
#  'watch_counts': '4'}
# 2020-11-24 19:21:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.daangn.com/articles/147226772> (referer: https://www.daangn.com/search/macbook/more/flea_market?page=1)
# 2020-11-24 19:21:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.daangn.com/articles/146083671> (referer: https://www.daangn.com/search/macbook/more/flea_market?page=1)
# 2020-11-24 19:21:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.daangn.com/articles/154390607> (referer: https://www.daangn.com/search/macbook/more/flea_market?page=1)
# 2020-11-24 19:21:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.daangn.com/articles/147226772>
# {'chat_counts': '3',
#  'desc': '제발 사실분들만 연락주세요 맥북에어 13인친 정말 아끼며 집에서만 사용한 맥북입니다사이클수 58인데 판매할때까지 충전은 '
#          '해야해서 올라갑니다초s급 이가격인 이유는 정말 집에서 아끼며 보관한거라 측정했습니다기본제공 연장케이블 쓰지도 않고 '
#          '보관중일본애플스토어 구매 한국 애플정품돼지코 장착되어있습니다용량128 램 4하자없고 케이블 박스 다보관중입니다거래는 '
#          '직거래만 합니다 택배거래도 가능하나 계좌이체순이고거래후 교환환불은 불가입니다그리고 '
#          '추가금교환및교환문의는대답안합니다택배비는5천원추가',
#  'link': 'https://www.daangn.com/articles/147226772',
#  'price': '700,000원',
#  'region': '마포구 상암동',
#  'temperature': '36.5',
#  'title': '2015 맥북 에어 128 4 맥북에어 모셔둔 애플 아이패드 프로',
#  'user_id': '카시나이키',
#  'view_counts': '903',
#  'watch_counts': '9'}
# 2020-11-24 19:21:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.daangn.com/articles/146083671>
# {'chat_counts': '7',
#  'desc': '2012년 중순 구입2012년 중순 구입용량은 60GB, 사이클 수는 1751. 큰 찍힘은 없습니다만 민감하신 분들은 '
#          '패스해주세요. 서로 확실히 하고자 사진 최대한 많이 찍어서 올립니다. 키보드도 문제없이 작동 잘 됩니다. 직거래만 '
#          '합니다. ',
#  'link': 'https://www.daangn.com/articles/146083671',
#  'price': '190,000원',
#  'region': '강남구 도곡동',
#  'temperature': '42.8',
#  'title': '맥북에어 MacBook Air 11인치 2012',
#  'user_id': '비우는마음',
#  'view_counts': '1532',
#  'watch_counts': '29'}
# 2020-11-24 19:21:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.daangn.com/articles/153549825> (referer: https://www.daangn.com/search/macbook/more/flea_market?page=1)
# 2020-11-24 19:21:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.daangn.com/articles/154390607>
# {'chat_counts': '0',
#  'desc': '맥북프로 13인치 2019년형 (모델명: A2159) 실버 팝니다. 스펙은 사진 참고해 주세요. 올해 3월초에 가로수길 '
#          '애플 프리스비에서 구매했습니다. 애플케어 (AppleCare+) 2023년 3월 10일까지입니다. 상태 S+ 급입니다. '
#          '하자 및 스크레치 없습니다. 서울 직거래만 합니다. 구입 당시 박스랑 충전기 애플 스티커 그리고 투명 보호 케이스 포함. ',
#  'link': 'https://www.daangn.com/articles/154390607',
#  'price': '1,690,000원',
#  'region': '관악구 신림동',
#  'temperature': '37.7',
#  'title': '맥북프로 13인치 2019형 256GB 실버 터치바/ MacBook Pro 13 inch',
#  'user_id': 'AppleBeats',
#  'view_counts': '48',
#  'watch_counts': '2'}
# 2020-11-24 19:21:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.daangn.com/articles/153549825>
# {'chat_counts': '1',
#  'desc': '제품명 : Macbook Air early 2015 13inch프로세서 : 1.6 GHz 듀얼코어 Intel Core i5 '
#          '구입일자 : 2016.03이번에 맥북프로로 넘어오면서 맥북에어 제품 판매합니다! 대학생때 매우 깔끔하게 사용해 제품 상태 '
#          '양호하며, 오른쪽 모서리에 생활 찍힘 외에는 기스도 거의 없는 제품입니다. 구성품은 충전기와 본체이며, 충전기가 조금은 '
#          '누렇게 변했지만 성능에는 전혀 이상없습니다! 일상적인 용도로 사용하실 목적이라면 휴대성, 배터리, 성능면에서 최적의 '
#          '노트북입니다~',
#  'link': 'https://www.daangn.com/articles/153549825',
#  'price': '380,000원',
#  'region': '강남구 역삼1동',
#  'temperature': '36.8',
#  'title': '[Macbook Air] 맥북에어 2015 13인치',
#  'user_id': 'Danggeun',
#  'view_counts': '216',
#  'watch_counts': '7'}
# 2020-11-24 19:21:33 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-11-24 19:21:33 [scrapy.extensions.feedexport] INFO: Stored csv feed (12 items) in: items.csv
# 2020-11-24 19:21:33 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 5060,
#  'downloader/request_count': 14,
#  'downloader/request_method_count/GET': 14,
#  'downloader/response_bytes': 107992,
#  'downloader/response_count': 14,
#  'downloader/response_status_count/200': 14,
#  'elapsed_time_seconds': 1.115068,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 11, 24, 10, 21, 33, 534515),
#  'item_scraped_count': 12,
#  'log_count/DEBUG': 26,
#  'log_count/INFO': 11,
#  'memusage/max': 56913920,
#  'memusage/startup': 56913920,
#  'request_depth_max': 1,
#  'response_received_count': 14,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 13,
#  'scheduler/dequeued/memory': 13,
#  'scheduler/enqueued': 13,
#  'scheduler/enqueued/memory': 13,
#  'start_time': datetime.datetime(2020, 11, 24, 10, 21, 32, 419447)}
# 2020-11-24 19:21:33 [scrapy.core.engine] INFO: Spider closed (finished)
# CPU times: user 39.3 ms, sys: 4.32 ms, total: 43.6 ms
# Wall time: 2.04 s

# %%
pd.read_csv("daangn/items.csv")
# Out:
#     chat_counts                                               desc  \
# 0             2  맥북프로 15인치 터치바 2017 기본형입니다2019년에 구입했고 실사용은 몇 달 ...
# 1             1  014년도 구입 최고사양 CTO 맥북 프로 A1278CPU : I7 최고사양 램 :...
# 2             0  맥북 프로 15인치 2013년도 고급형 판매합니다.i7 2.3 쿼드코어입니다.풀박이...
# 3             0  맥북에어[Macbook air] 판매합니다13인치이고 케이스 착용하고 조심히 사용해...
# 4             5  맥북프로 레티나 13인치 입니다액정은 기본 필름입니다.하단 배면부 생활기스 있습니다...
# 5             0  MacBook Pro 맥북프로 13인치 Mid 2014 레티나 A1502현재 최신 ...
# 6             5                박스랑 충전기까지 드립니다.기스랑 찍힘 있으니 사진 참고해주세요
# 7             0                                                 서울
# 8             1  * 256GB* 최근 수리* 포맷완료* 풀박스* 직거래해요* 깨끗하게 쓰시라고 알코...
# 9             1  제품명 : Macbook Air early 2015 13inch프로세서 : 1.6 ...
# 10            0  맥북프로 13인치 2019년형 (모델명: A2159) 실버 팝니다. 스펙은 사진 참...
# 11            0  맥북 에어 2014 13인치 ssd 128g프로세서 1.4GHz 듀얼코어 intel...
#
#                                          link       price         region  \
# 0   https://www.daangn.com/articles/150455627  1,500,000원        당진시 채운동
# 1   https://www.daangn.com/articles/154330347    400,000원        공주시 금학동
# 2   https://www.daangn.com/articles/154263336    850,000원    수원시 영통구 망포동
# 3   https://www.daangn.com/articles/151032265    530,000원    성남시 분당구 금곡동
# 4   https://www.daangn.com/articles/146403990    500,000원        금천구 가산동
# 5   https://www.daangn.com/articles/154245784    550,000원    용인시 기흥구 동백동
# 6   https://www.daangn.com/articles/146539023    600,000원        관악구 신림동
# 7   https://www.daangn.com/articles/154383568    720,000원        남구 신정3동
# 8   https://www.daangn.com/articles/151356238    800,000원        성동구 행당동
# 9   https://www.daangn.com/articles/153549825    380,000원       강남구 역삼1동
# 10  https://www.daangn.com/articles/154390607  1,690,000원        관악구 신림동
# 11  https://www.daangn.com/articles/154383587    430,000원  고양시 일산서구 일산1동
#
#     temperature                                              title  \
# 0          37.0      Macbook Pro 15inch 맥북 프로 15인치 2017년 (스페이스그레이)
# 1          36.5                    맥북프로 I7 CPU A1278프리미엄 맥북 - 최고사양
# 2          36.7  Macbook Pro (Retina, 15-inch, Late 2013) 맥북 프로...
# 3          35.7                        MaCbook air 맥북/멕북 노트북 판매합니다
# 4          36.5             애플 맥북 프로 레티나 MacBook Pro A1502 13인치 판매
# 5          40.3                 MacBook Pro 맥북프로 13인치 Mid 2014 레티나
# 6          37.0             13인치 Macbook air 맥북에어 2017년형 256기가 팝니다
# 7          38.4                                   맥북 12인치 뉴맥북 2017
# 8          36.5      맥북프로 Macbook Pro, 13인치 Early 2015 & 애플 매직마우스2
# 9          36.8                       [Macbook Air] 맥북에어 2015 13인치
# 10         37.7  맥북프로 13인치 2019형 256GB 실버 터치바/ MacBook Pro 13 inch
# 11         44.2                          맥북에어13인치 2014 Macbook Air
#
#        user_id  view_counts  watch_counts
# 0   windsurfer          139             0
# 1          김소연           53             0
# 2          최의현           81             1
# 3          야도르          235             4
# 4           네오          733             7
# 5         cwru           49             2
# 6          도야지          865            15
# 7           하늘           11             1
# 8           채니          469            15
# 9     Danggeun          205             6
# 10  AppleBeats           47             2
# 11        당근왕검           27             0
